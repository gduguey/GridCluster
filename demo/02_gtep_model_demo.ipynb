# %% [markdown]
# # GTEP Model Demo
#
# This notebook introduces the Generation and Transmission Expansion Planning (GTEP) model.
# It explains the required input format, presents the mathematical formulation, and demonstrates how
# to run the optimization. It also covers spatial and temporal deaggregation of solutions.
#
# **Purpose**: Show how to set up and run the GTEP model on aggregated input data, and how to recover
# fine-scale outputs.
# **Inputs**: CSV input datasets (not necessarily from the aggregation pipeline)
# **Outputs**: Optimization results and deaggregated results under `<Your_Specified_Path>/results/`

# %%
import sys
import pathlib

PROJECT_ROOT = pathlib.Path().cwd().parent
sys.path.append(str(PROJECT_ROOT))

# %% [markdown]
# ## 1) What the aggregated GTEP expects as input
#
# The **GTEP module can be used independently**. It expects data in the following shapes (pandas DataFrames):
#
# - **Buses**: columns `['bus_id', 'Lat', 'Lon']`, one row per bus.
# - **Branches**: columns `['branch_id','from_bus_id','to_bus_id']`, one row per line.
# - **RepPeriod** (time series):
#     - `Load`: shape **T × B** (hours × buses), numeric
#     - `PV`: shape **T × B**, numeric (capacity factors or per-bus availability factors)
#     - `Wind`: shape **T × B**, numeric

# %%
from src.gtep.types import RepPeriod, InputData, Params
import pandas as pd
import numpy as np

# build your own (toy) dataframes:
B, T = 5, 24*10
buses = pd.DataFrame({"bus_id": range(B), "Lat": np.linspace(40,45,B), "Lon": np.linspace(-73,-70,B)})
branches = pd.DataFrame(
    [{"branch_id": i*B+j, "from_bus_id": i, "to_bus_id": j}
     for i in range(B) for j in range(i+1, B)]
)
Load = pd.DataFrame(100 + 20*np.random.rand(T, B), columns=buses.bus_id)
PV   = pd.DataFrame(np.clip(np.random.rand(T, B), 0, 1), columns=buses.bus_id)
Wind = pd.DataFrame(np.clip(np.random.rand(T, B), 0, 1), columns=buses.bus_id)

# Use the utils to scale and package
params = Params(
    Initial_SOC=0.5, eta_discharge=0.92, eta_charge=0.92,
    PV_resource=1e5, Wind_resource=5e4,
    CCGT_ramp=0.05, CCGT_max_cap=640.0,
    c_ccgt=1.0, c_pv=1.0, c_wind=1.0, c_storage=1.0, c_tran=1.0,
    d_ccgt=1.0, d_shed=100.0,
    rate_duration=4, MW_per_mile=30.0,
    TranMax={i:1000.0 for i in branches.index}, Length={i:10.0 for i in branches.index}
)
data = InputData(buses=buses, branches=branches, rep_period=RepPeriod(Load, PV, Wind), params=params)
print("Buses:", data.buses.shape, "Branches:", data.branches.shape, "T:", data.rep_period.T)
# Out:
# Buses: (5, 3) Branches: (10, 3) T: 240

# %% [markdown]
# Alternatively, you can pass an **aggregation block** to `build_input_data(...)`, which converts it into the exact `InputData` structure.

# %%
from src.aggregation.pipeline import StaticPreprocessor, DynamicProcessor
from src.gtep.utils import build_input_data

# We get "agg_spatiotemporal" from the aggregation pipeline:
preproc = StaticPreprocessor(granularity="coarse", year=2013).preprocess()
dyn = DynamicProcessor(preprocessor=preproc)

weights={
        'position': 1.0,
        'time_series': 0.8,
        'duration_curves': 1.2,
        'ramp_duration_curves': 1.0,
        'intra_correlation': 1.0,
        'inter_correlation': 1.0
    }

results, version_hash, day_weights, metadata = dyn.run_with_hyperparameters(
    weights=weights,
    n_representative_nodes=10,
    k_representative_days=12
)

agg_spatiotemporal = results["spatiotemporal"]

# We can now build the input data for the GTEP model
data = build_input_data(agg_spatiotemporal, power_scale="GW", cost_scale="M$", sig_round=3, verbose=True)
print("Buses:", data.buses.shape, "Branches:", data.branches.shape, "T:", data.rep_period.T)
# Out:
# c:\Users\g630d\Documents\00_Academic\2024-2025_MIT\Research\2024 09 Thesis\Code\src\aggregation\utils.py:140: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   counties.geometry.centroid.y,
# c:\Users\g630d\Documents\00_Academic\2024-2025_MIT\Research\2024 09 Thesis\Code\src\aggregation\utils.py:141: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   counties.geometry.centroid.x
# Cached metrics loaded from C:\Users\g630d\Documents\00_Academic\2024-2025_MIT\Research\2024 09 Thesis\Code\results\distance_metrics\v202586c2.
# Results saved to C:\Users\g630d\Documents\00_Academic\2024-2025_MIT\Research\2024 09 Thesis\Code\results\joint_aggregation_results\v4b02ae39
# === DATA LOADING ===
# PV shape  (288, 10)
# Wind shape  (288, 10)
# Load shape  (288, 10)
#
#
# === SCALING CHECK ===
# Power: MW → GW (×0.001), Cost: $ → M$ (×1e-06)
#     PV CF range: [0, 0.866]
#     Wind CF range: [0, 1]
#     Load range MW → GW:  [605, 1.04e+04] → [0.605, 10.4]
#     Param range: [30.6, 2.36e+06] → [0.0306, 2.36e+03]
#
# Buses: (10, 3) Branches: (45, 3) T: 288

# %% [markdown]
# ## 2) Model description
#
# The **aggregated Generation and Transmission Expansion Planning (GTEP) model** is formulated as a transport-based MILP. The model co-optimizes investment and operation decisions across representative hours and aggregated zones. It captures demand, renewable profiles, storage dynamics, and transmission flows, while enforcing simplified operational limits.
#
# ### Sets and parameters
#
# | **Symbol** | **Meaning** |
# |:--:|:--:|
# | $\mathcal{C}$ | Set of zones (clusters) |
# | $\mathcal{T}_{\text{agg}}$ | Set of representative time steps $t$ with weight $\omega_t$ |
# | $\mathcal{G}_{\text{disp}}$ | Dispatchable technologies (e.g. gas) |
# | $\mathcal{G}_{\text{var}}$ | Variable renewables (e.g. wind, solar) |
# | $\mathcal{E}$ | Transmission links $(c,c')$ |
# | $D^d_c(t)$ | Demand in zone $c$ at time $t$ |
# | $a_c^g(t)$ | Availability factor of renewable $g$ in $c$ at $t$ |
# | $\bar{P}_g$ | Per-unit capacity of technology $g$ |
# | $r_g$ | Ramp rate of dispatchable $g$ |
# | $\Gamma_g^{\max}$ | Max installable potential of renewable $g$ |
# | $\eta^{ch}, \eta^{dis}$ | Storage charge/discharge efficiency |
# | $\tau$ | Max storage duration (energy-to-power ratio) |
#
#
# ### Decision variables
#
# **Investments (per zone $c$):**
# - $G_c^g$: capacity of technology $g$ (integer if dispatchable, real if renewable)
# - $S_c$: storage power capacity
# - $T_{cc'}$: transmission capacity on link $(c,c')$
#
# **Operations (per $t$):**
# - $P_c^g(t)$: generation dispatch
# - $q_c^g(t)$: curtailment of renewable $g$
# - $\ell_c(t)$: load shedding
# - $f_{cc'}(t)$: flow on link $(c,c’)$
# - $C_c(t), D_c(t)$: storage charge and discharge
# - $e_c(t)$: storage energy level
#
# ### Constraints
#
# **Power balance (per zone, per $t$):**
# $$
# \sum_g P_c^g(t) + D_c(t) - C_c(t)
# + \sum_{c'} f_{c'c}(t) - \sum_{c'} f_{cc'}(t)
# + \ell_c(t) = D^d_c(t)
# $$
#
# **Generation capacity and renewables:**
# $$
# P_c^g(t) \le G_c^g \cdot \bar{P}_g \quad (g \in \mathcal{G}_{\text{disp}})
# $$
# $$
# P_c^g(t) + q_c^g(t) = G_c^g \cdot a_c^g(t) \quad (g \in \mathcal{G}_{\text{var}})
# $$
#
# **Ramping (dispatchables):**
# $$
# |P_c^g(t) - P_c^g(t-1)| \le G_c^g \cdot \bar{P}_g \cdot r_g
# $$
#
# **Storage dynamics:**
# $$
# e_c(t) = e_c(t-1) + \eta^{ch} C_c(t) - \tfrac{1}{\eta^{dis}} D_c(t)
# $$
# $$
# 0 \le C_c(t), D_c(t) \le S_c, \quad 0 \le e_c(t) \le \tau S_c
# $$
#
# **Transmission limits:**
# $$
# - T_{cc'} \le f_{cc'}(t) \le T_{cc'} \quad \forall (c,c')
# $$
#
# **Resource potentials:**
# $$
# \sum_c G_c^g \le \Gamma_g^{\max} \quad (g \in \mathcal{G}_{\text{var}})
# $$
#
# ### Objective
#
# The objective minimizes investment and weighted operating costs:
# $$
# \min \ \sum_{c,g} C_g^{inv} G_c^g
# + \sum_c C_S^{inv} S_c
# + \sum_{(c,c')} C_T^{inv} T_{cc'}
# + \sum_{t \in \mathcal{T}_{\text{agg}}} \omega_t \sum_c
# \Big( \sum_{g \in \mathcal{G}_{\text{disp}}} \varphi_g P_c^g(t) + \psi \ell_c(t) \Big)
# $$
#
# This formulation treats dispatchable investments as integer (discrete units) and all other capacities as continuous, ensuring tractability while capturing essential planning trade-offs.
#
# Results are stored under the folders: `<Your_Specified_Path>/results/gtep_output/aggregated/` in pickle format `aggregated_<aggregation_hash>_<gtep_hash>.pkl`, as a RunArtifacts dataclass, defined in `src/gtep/types.py`.

# %% [markdown]
# ---
# You can either use the provided `run_aggregated` helper function that builds `InputData` for the GTEP based on the aggregation pipeline results and runs the aggregated GTEP:

# %%
from pathlib import Path
from src.gtep.pipeline import run_aggregated

day_weights_list = list(day_weights.values())
# You can also use a dummy uniform day-weights if you built your own data:
# from gtep.utils import uniform_day_weights
# day_weights = uniform_day_weights(data.rep_period.T)

# Running Aggregated GTEP:
exp_root = Path(".")
art_agg = run_aggregated(results, agg_hash=version_hash, exp_root=exp_root, day_weights=day_weights_list, threads=4)
print("Saved:", art_agg.save_path, "Log:", art_agg.log_path)
# Out:
# === DATA LOADING ===
# PV shape  (288, 10)
# Wind shape  (288, 10)
# Load shape  (288, 10)
#
#
# === SCALING CHECK ===
# Power: MW → GW (×0.001), Cost: $ → M$ (×1e-06)
#     PV CF range: [0, 0.866]
#     Wind CF range: [0, 1]
#     Load range MW → GW:  [605, 1.04e+04] → [0.605, 10.4]
#     Param range: [30.6, 2.36e+06] → [0.0306, 2.36e+03]
#
# Set parameter Username
# Set parameter TimeLimit to value 7200
# Set parameter Threads to value 4
# Academic license - for non-commercial use only - expires 2026-08-14
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 4 threads
#
# Non-default parameters:
# TimeLimit  7200
# Threads  4
#
# Optimize a model with 49007 rows, 30325 columns and 147928 nonzeros
# Model fingerprint: 0x5b6e1e10
# Variable types: 30315 continuous, 10 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 4e+00]
#   Objective range  [3e-01, 7e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e-01, 2e+03]
# Presolve removed 85 rows and 2910 columns
# Presolve time: 0.18s
# Presolved: 48922 rows, 27415 columns, 144913 nonzeros
# Variable types: 27405 continuous, 10 integer (0 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 48922 rows, 27415 columns, 144913 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    27486    1.5201015e+04   0.000000e+00   1.378023e+06      5s
#    40158    1.4179465e+04   0.000000e+00   2.647292e+06     10s
#    46738    1.3693199e+04   0.000000e+00   4.181728e+06     15s
#    51838    1.3362628e+04   0.000000e+00   3.723509e+05     20s
#    56456    1.3001630e+04   0.000000e+00   2.306322e+07     25s
#    60436    1.2820531e+04   0.000000e+00   7.992442e+05     30s
56
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.427919672449e+03, best bound 9.426991626428e+03, gap 0.0098%
#
# User-callback calls 48447, time in user-callback 0.74 sec
# Saved full RunArtifacts to results\gtep_output\aggregated\aggregated_4b02ae39_92c4c95f.pkl
# Saved: results\gtep_output\aggregated\aggregated_4b02ae39_92c4c95f.pkl Log: results\gtep_logs\aggregated\aggregated_4b02ae39_92c4c95f.csv

# %% [markdown]
# Or you can use your own data, transform it yourself in `InputData` as seen in part 1), and manually run the `AggregatedGTEP` (NB, you will still need to have the cluster medoids and members):

# %%
import gurobipy as gp
import hashlib
import json
from dataclasses import asdict
from src.gtep.models import AggregatedGTEP
from src.gtep.types import RunArtifacts
from src.gtep.utils import SolveLogger
from src.gtep.pipeline import save_artifacts

# See part 1) of this notebook to build the data
agg_hash = version_hash # from the aggregation pipeline, or a Dummy Hash
agg_results = results
day_weights_list = list(day_weights.values())

# Manually set parameters and solve the aggregated GTEP
threads = 4
gtep_hash = hashlib.md5(json.dumps(asdict(data.params), sort_keys=True).encode()).hexdigest()[:8]
log_path = exp_root / "results" / "gtep_logs" / "aggregated" / f"aggregated_{agg_hash}_{gtep_hash}.csv"
clusters = agg_results["clusters"]
with gp.Env(empty=True) as env:
    env.setParam('OutputFlag', 1)
    env.setParam("Threads",   threads)
    env.setParam("TimeLimit", 2 * 60 * 60) # in seconds
    env.start()
    logger = SolveLogger(log_path)
    model = AggregatedGTEP(env, data.buses, data.branches, data.params)
    try:
        res = model.optimize(data.rep_period, day_weights_list, logger)
    except RuntimeError as e:
        if "No feasible solution" in str(e):
            print(f"[{agg_hash}] Infeasible aggregated GTEP → skipping")
            res = None
        else:
            raise
art_agg = RunArtifacts(
    results=res,
    data=data,
    agg_hash=agg_hash,
    gtep_hash=gtep_hash,
    save_path=None,
    log_path=log_path,
    clusters=clusters
)
if res is not None:
    art_agg.save_path = save_artifacts(art_agg, "aggregated", exp_root)
# Out:
# Set parameter Username
# Set parameter TimeLimit to value 7200
# Set parameter Threads to value 4
# Academic license - for non-commercial use only - expires 2026-08-14
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 4 threads
#
# Non-default parameters:
# TimeLimit  7200
# Threads  4
#
# Optimize a model with 49007 rows, 30325 columns and 147928 nonzeros
# Model fingerprint: 0x5b6e1e10
# Variable types: 30315 continuous, 10 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 4e+00]
#   Objective range  [3e-01, 7e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e-01, 2e+03]
# Presolve removed 85 rows and 2910 columns
# Presolve time: 0.15s
# Presolved: 48922 rows, 27415 columns, 144913 nonzeros
# Variable types: 27405 continuous, 10 integer (0 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 48922 rows, 27415 columns, 144913 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    26483    1.5250200e+04   0.000000e+00   4.915456e+05      5s
#    39268    1.4321456e+04   0.000000e+00   4.282874e+06     10s
#    44468    1.3897016e+04   0.000000e+00   8.196811e+05     15s
#    49948    1.3463717e+04   0.000000e+00   6.514182e+05     20s
#    55168    1.3140234e+04   0.000000e+00   7.984553e+05     25s
#    59386    1.2861190e+04   0.000000e+00   1.605392e+05     30s
#    62746    1.2699799e+04   0.000000e+00   4.940561e+05     35s
#    65956    1.2537461e+04   0.000000e+00   3.275659e+05     40s
#    69166    1.2391951e+04   0.000000e+00   1.114805e+06     45s
#    72166    1.2239596e+04   0.000000e+00   3.912560e+05     50s
#    74916    1.2078405e+04   0.000000e+00   7.395953e+05     55s
#    77686    1.1934133e+04   0.000000e+00   3.278000e+05     60s
56
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.427919672449e+03, best bound 9.426991626428e+03, gap 0.0098%
#
# User-callback calls 67739, time in user-callback 1.45 sec
# Saved full RunArtifacts to results\gtep_output\aggregated\aggregated_4b02ae39_92c4c95f__1.pkl

# %% [markdown]
# ## 4) Spatial & temporal de-aggregation
#
# We evaluate aggregated solutions using a **two-stage de-aggregation procedure**. This ensures feasibility under the same physical and operational rules as the full GTEP model.
#
# ### 1. Spatial de-aggregation
#
# For each cluster $c$ and generation technology $g$, node-level investments must reproduce the aggregated totals:
#
# $$
# \sum_{i \in c} G_i^g = G_c^g,
# \quad \sum_{i \in c} S_i = S_c
# $$
#
# Transmission is treated similarly. For each aggregated link $(c,c')$, with set of physical lines
# $\mathcal{E}_{cc'} = \{(i,j): i \in c,\, j \in c'\}$, we impose:
#
# $$
# \sum_{(i,j)\in \mathcal{E}_{cc'}} T_{ij} = T_{cc'}
# $$
#
# These equalities preserve the aggregated capacities while letting the optimizer decide their distribution across nodes and lines. All other operational constraints remain the same as in the aggregated model.
#
# ### 2. Temporal de-aggregation
#
# After spatial allocation, investments are **fixed**, and the operational MILP is re-solved over the full chronological horizon $\mathcal{T} = \{1, \dots, 8760\}$ with **uniform day weights**.
#
# The objective minimizes real operating costs and penalties for load shedding, subject to dispatch, storage, and flow constraints. This step tests whether the aggregated plan remains feasible under chronological flexibility requirements.
#
# ### Outputs
#
# Results are stored in the same format as the aggregated runs, but under the folders:
#
# - `<Your_Specified_Path>/results/gtep_output/spatial/` for Stage 1 (spatial allocation)
# - `<Your_Specified_Path>/results/gtep_output/temporal/` for Stage 2 (full chronological operation)

# %%
from src.gtep.pipeline import run_spatial, run_temporal

# Given aggregated results/artifacts:
if art_agg.results:
    art_sp = run_spatial(results, agg_hash=version_hash, exp_root=exp_root, day_weights=day_weights_list, agg_inv=art_agg.results.inv, threads=4)
    if art_sp.results:
        art_tm = run_temporal(results, agg_hash=version_hash, exp_root=exp_root, fixed_inv=art_sp.results.inv, threads=4)
print("Artifacts saved under <Your_Specified_Path>/results/gtep_output/{spatial|temporal}/")
# Out:
# === DATA LOADING ===
# PV shape  (288, 17)
# Wind shape  (288, 17)
# Load shape  (288, 17)
#
#
# === SCALING CHECK ===
# Power: MW → GW (×0.001), Cost: $ → M$ (×1e-06)
#     PV CF range: [0, 0.866]
#     Wind CF range: [0, 1]
#     Load range MW → GW:  [449, 5.83e+03] → [0.449, 5.83]
#     Param range: [30.6, 2.36e+06] → [0.0306, 2.36e+03]
#
# Set parameter Username
# Set parameter TimeLimit to value 14400
# Set parameter Threads to value 4
# Academic license - for non-commercial use only - expires 2026-08-14
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 4 threads
#
# Non-default parameters:
# TimeLimit  14400
# Threads  4
#
# Optimize a model with 117727 rows, 68748 columns and 354540 nonzeros
# Model fingerprint: 0x2f3f3391
# Variable types: 68731 continuous, 17 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 4e+00]
#   Objective range  [3e-01, 7e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-03, 2e+03]
# Found heuristic solution: objective 1517682.4728
# Presolve removed 37205 rows and 19173 columns
# Presolve time: 0.40s
# Presolved: 80522 rows, 49575 columns, 242305 nonzeros
# Variable types: 49566 continuous, 9 integer (0 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    47689    1.4793502e+05   0.000000e+00   3.253130e+08      5s
#    63954    8.7704570e+04   0.000000e+00   1.133081e+07     10s
#    71495    5.2941759e+04   0.000000e+00   7.837467e+07     15s
#    75998    4.1062251e+04   0.000000e+00   5.905541e+07     20s
#    79691    2.9485474e+04   0.000000e+00   1.984983e+07     25s
#    82995    1.9823767e+04   0.000000e+00   2.251674e+07     30s
#    86348    1.5855131e+04   0.000000e+00   8.184492e+06     35s
#    89439    1.3772092e+04   0.000000e+00   4.002900e+07     40s
#    92850    1.2882887e+04   0.000000e+00   6.239927e+06     45s
#   53   2.32617700e+04  2.32617558e+04  1.38e-08 7.11e-15  6.01e-09    71s
#   54   2.32617678e+04  2.32617572e+04  1.10e-08 7.11e-15  4.49e-09    72s
#   55   2.32617614e+04  2.32617588e+04  2.87e-09 7.11e-15  1.14e-09    74s
#   56   2.32617594e+04  2.32617591e+04  2.96e-10 7.11e-15  1.34e-10    75s
#   57   2.32617592e+04  2.32617592e+04  2.89e-10 8.60e-15  3.81e-12    76s
#
# Barrier solved model in 57 iterations and 76.50 seconds (38.01 work units)
# Optimal objective 2.32617592e+04
#
# Crossover log...
#
#    66155 DPushes remaining with DInf 0.0000000e+00                78s
#        0 DPushes remaining with DInf 0.0000000e+00                79s
#
#   365625 PPushes remaining with PInf 5.9779468e-03                80s
#   284362 PPushes remaining with PInf 0.0000000e+00                80s
#   180485 PPushes remaining with PInf 0.0000000e+00                85s
#   150719 PPushes remaining with PInf 0.0000000e+00                90s
#   129083 PPushes remaining with PInf 0.0000000e+00                95s
#   103702 PPushes remaining with PInf 0.0000000e+00               100s
#    47628 PPushes remaining with PInf 0.0000000e+00               105s
#        0 PPushes remaining with PInf 0.0000000e+00               109s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.4129798e-13    109s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   406469    2.3261759e+04   0.000000e+00   0.000000e+00    111s
#
# Solved in 406469 iterations and 111.48 seconds (52.11 work units)
# Optimal objective  2.326175916e+04
#
# User-callback calls 414725, time in user-callback 1.18 sec
# Saved full RunArtifacts to results\gtep_output\temporal\temporal_4b02ae39_d3ecd59c.pkl
# Artifacts saved under results/gtep_output/{spatial|temporal}/

# %% [markdown]
# ## 5) Running the pipeline end-to-end (parallel vs simple)
#
# Use `run_experiment` to iterate over multiple (N, K, weights) cases.
#
# - Set `threads` to control Gurobi’s parallelism per run.
# - Use `consume(...)` to build a manifest of results (hashes, paths, objectives).

# %%
from src.gtep.pipeline import run_experiment, consume

# 1) Build aggregated data (choose "coarse" 17 zones OR "fine" 385 nodes) from part 1) of this notebook
# pre = StaticPreprocessor(granularity="coarse", year=2013).preprocess()
# dyn = DynamicProcessor(preprocessor=pre)

# 2) Define a tiny grid of hyperparameters
grid = [
    {"id":"case_01","desc":"C10-D12","n_representative_nodes":10,"k_representative_days":12,
     "weights":{"position":0.4,"time_series":0.4,"duration_curves":0.2,"ramp_duration_curves":0.2,"intra_correlation":0.1,"inter_correlation":0.4}},
    {"id":"case_02","desc":"C12-D16","n_representative_nodes":12,"k_representative_days":16,
     "weights":{"position":0.4,"time_series":0.4,"duration_curves":0.2,"ramp_duration_curves":0.2,"intra_correlation":0.1,"inter_correlation":0.4}},
]

# 3) Run GTEP pipeline
exp_root = Path(".")
gen = run_experiment(grid, dyn, exp_root=exp_root, threads=8)

# 4) Collect results into a manifest
manifest = consume(gen, root=exp_root)
print(manifest)
# Out:
# === Starting case case_01 (N=10, K=12) ===
# [case_01] Running aggregation...
# Cached metrics loaded from C:\Users\g630d\Documents\00_Academic\2024-2025_MIT\Research\2024 09 Thesis\Code\results\distance_metrics\v202586c2.
# Results saved to C:\Users\g630d\Documents\00_Academic\2024-2025_MIT\Research\2024 09 Thesis\Code\results
work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 9409.16111    0    8          - 9409.16111      -     -  205s
# H    0     0                    9779.3531738 9409.16111  3.79%     -  205s
# H    0     0                    9410.4018511 9409.16111  0.01%     -  212s
#      0     0 9409.16331    0    8 9410.40185 9409.16331  0.01%     -  213s
#      0     2 9409.16331    0    8 9410.40185 9409.16331  0.01%     -  218s
#      1     4 9409.63565    1    7 9410.40185 9409.17190  0.01%  3212  223s
#
# Explored 3 nodes (102438 simplex iterations) in 223.81 seconds (135.38 work units)
# Thread count was 8 (of 12 available processors)
#
# Solution count 2: 9410.4 9779.35
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.410401851128e+03, best bound 9.409636743661e+03, gap 0.0081%
#
# User-callback calls 68984, time in user-callback 1.31 sec
# Saved full RunArtifacts to results\gtep_output\aggregated\aggregated_8a7dce83_bca22cb9.pkl
# [case_01] Aggregated GTEP solved with objective 9410.40185112794
# [case_01] Solving spatial de-aggregation GTEP...
# === DATA LOADING ===
# PV shape  (288, 17)
# Wind shape  (288, 17)
# Load shape  (288, 17)
#
#
# === SCALING CHECK ===
# Power: MW → GW (×0.001), Cost: $ → M$ (×1e-06)
#     PV CF range: [0, 0.866]
#     Wind CF range: [0, 1]
#     Load range MW → GW:  [421, 5.83e+03] → [0.421, 5.83]
#     Param range: [30.6, 2.36e+06] → [0.0306, 2.36e+03]
#
# Set parameter Username
# Set parameter TimeLimit to value 14400
# Set parameter Threads to value 8
# Academic license - for non-commercial use only - expires 2026-08-14
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  14400
# Threads  8
#
# Optimize a model with 117727 rows, 68748 columns and 354545 nonzeros
# Model fingerprint: 0x7d8da20b
# Variable types: 68731 continuous, 17 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 4e+00]
#   Objective range  [3e-01, 7e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e-02, 2e+03]
# Found heuristic solution: objective 1558915.9744
# Presolve removed 36710 rows and 18987 columns
# Presolve time: 0.42s
# Presolved: 81017 rows, 49761 columns, 244033 nonzeros
# Variable types: 49752 continuous, 9 integer (1 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    54766    2.2164581e+05   0.000000e+00   8.516403e+07      5s
#    64750    1.1025540e+05   0.000000e+00   1.127019e+08     10s
#    69348    6.6751986e+04   0.000000e+00   2.745281e+08     15s
#    73019    5.3127557e+04   0.000000e+00   1.801165e+08     20s
#    75851    4.5542302e+04   0.000000e+00   7.602318e+07     25s
#    78583    3.8271344e+04   0.000000e+00   1.747005e+07     30s
#    80977    3.2273202e+04   0.000000e+00   4.667439e+07     35s
#    83427    2.8764296e+04   0.000000e+00   1.036016e+07     40s
#    85747    2.4757006e+04   0.000000e+00   1.074795e+07     45s
#    87578    2.2278861e+04   0.000000e+00   2.317469e+07     50s
#    89778    1.9393908e+04   0.000000e+00   1.549991e+07     55s
#    91688    1.7896206e+04   0.000000e+00   2.260533e+07     60s
#    94088    1.6093574e+04   0.000000e+00   1.574721e+07     65s
#    96068    1.5225846e+04   0.000000e+00   2.090394e+06     70s
#    98308    1.4523821e+04   0.000000e+00   2.293618e+07     75s
#   100388    1.3780693e+04   0.000000e+00   2.501895e+07     80s
#   102428    1.3385869e+04   0.000000e+00   2.529891e+06     85s
#   104128    1.2957727e+04   0.000000e+00   4.986064e+06     90s
#   105858    1.2640440e+04   0.000000e+00   3.657605e+06     95s
#   107889    1.2395196e+04   0.000000e+00   1.761509e+06    100s
#   109689    1.2156853e+04   0.000000e+00   1.951468e+07    105s
#   184283    9.6557815e+03   0.000000e+00   2.078170e+06    340s
#   185493    9.6426093e+03   0.000000e+00   1.206742e+06    345s
#   186693    9.6288489e+03   0.000000e+00   3.081181e+05    350s
#   187953    9.6174563e+03   0.000000e+00   2.149561e+05    355s
#   189093    9.6076426e+03   0.000000e+00   4.995673e+05    360s
#   190333    9.5979912e+03   0.000000e+00   3.859870e+05    365s
#   191663    9.5898182e+03   0.000000e+00   8.691037e+04    370s
#   192673    9.5809960e+03   0.000000e+00   1.567484e+05    375s
#   193883    9.5739562e+03   0.000000e+00   5.573693e+04    380s
#   195023    9.5679711e+03   0.000000e+00   4.835259e+05    385s
#   196093    9.5619912e+03   0.000000e+00   2.390819e+05    390s
#   197363    9.5555490e+03   0.000000e+00   1.093507e+06    395s
#   198603    9.5519375e+03   0.000000e+00   1.463549e+05    400s
#   199753    9.5483013e+03   0.000000e+00   3.999257e+05    405s
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   393346    9.5182137e+03   0.000000e+00   0.000000e+00    405s
#
# Root relaxation: objective 9.518214e+03, 393346 iterations, 404.60 seconds (314.53 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 9518.21366    0    8 1558915.97 9518.21366  99.4%     -  405s
# H    0     0                    9521.6294529 9518.21366  0.04%     -  429s
#      0     0 9518.22335    0    8 9521.62945 9518.22335  0.04%     -  430s
#      0     2 9518.22742    0    8 9521.62945 9518.22742  0.04%     -  491s
#      1     2 9518.87921    1    7 9521.62945 9518.22742  0.04%  5656  518s
#      3     1     cutoff    2      9521.62945 9518.91645  0.03% 11113  529s
#      4     2 9520.87340    2    6 9521.62945 9520.87340  0.01%  8445  530s
#
# Explored 5 nodes (427124 simplex iterations) in 530.55 seconds (474.05 work units)
# Thread count was 8 (of 12 available processors)
#
# Solution count 2: 9521.63 1.55892e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.521629452918e+03, best bound 9.520880281952e+03, gap 0.0079%
#
# User-callback calls 162429, time in user-callback 2.22 sec
# Saved full RunArtifacts to results\gtep_output\spatial\spatial_8a7dce83_d3ecd59c.pkl
# [case_01] Spatial results saved to results\gtep_output\spatial\spatial_8a7dce83_d3ecd59c.pkl with objective 9521.629452918358
# [case_01] Solving temporal de‑aggregation GTEP...
# === DATA LOADING ===
# PV shape  (8760, 17)
# Wind shape  (8760, 17)
# Load shape  (8760, 17)
#
#
# === SCALING CHECK ===
# Power: MW → GW (×0.001), Cost: $ → M$ (×1e-06)
#     PV CF range: [0, 0.866]
#     Wind CF range: [0, 1]
#     Load range MW → GW:  [401, 6.13e+03] → [0.401, 6.13]
#     Param range: [30.6, 2.36e+06] → [0.0306, 2.36e+03]
#
# Set parameter Username
# Set parameter TimeLimit to value 7200
# Set parameter Threads to value 8
# Academic license - for non-commercial use only - expires 2026-08-14
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  7200
# Threads  8
#
# Optimize a model with 3574080 rows, 2084880 columns and 7297029 nonzeros
# Model fingerprint: 0xfdd81768
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+00]
#   Objective range  [3e-02, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-06, 1e+01]
# Presolve removed 3035334 rows and 967559 columns (presolve time = 5s)...
# Presolve removed 3157996 rows and 967908 columns
# Presolve time: 6.48s
# Presolved: 416084 rows, 1239612 columns, 2325763 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Elapsed ordering time = 5s
# Ordering time: 6.66s
#
# Barrier statistics:
#  AA' NZ     : 1.061e+06
#  Factor NZ  : 2.343e+07 (roughly 900 MB of memory)
#  Factor Ops : 3.697e+09 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5
#     78    24 9653.69150    6    5 9653.81003 9652.18298  0.02%  9672 2007s
#     80    23     cutoff    7      9653.81003 9652.18298  0.02% 10080 2117s
#     81    21     cutoff    7      9653.81003 9652.18298  0.02%  9956 2223s
#     83    23 9652.57710    5    6 9653.81003 9652.18298  0.02%  9807 2337s
#     85    29 9653.58842    7    3 9653.81003 9652.18298  0.02%  9701 2444s
#     93    34     cutoff    8      9653.81003 9652.18298  0.02%  9982 2546s
#    112    29     cutoff   11      9653.81003 9652.18298  0.02%  9347 2639s
# *  117    29              11    9653.8002921 9652.18298  0.02%  9554 2639s
#    121    21     cutoff    8      9653.80029 9652.18298  0.02%  9351 2725s
#    133    19 9653.46320    9    1 9653.80029 9652.18298  0.02%  8856 2806s
#    139     7     cutoff    6      9653.80029 9652.18298  0.02%  8593 2859s
# *  143     7              10    9653.4699289 9652.18298  0.01%  8517 2859s
#    153     8 9652.97006    5    5 9653.46993 9652.18298  0.01%  8054 2915s
#    160     7 9653.16201    6    5 9653.46993 9652.18298  0.01%  8082 2989s
#
# Cutting planes:
#   MIR: 22
#
# Explored 169 nodes (1632393 simplex iterations) in 2989.54 seconds (2044.11 work units)
# Thread count was 8 (of 12 available processors)
#
# Solution count 6: 9653.47 9653.8 9653.81 ... 2.36641e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.653469928912e+03, best bound 9.652597277353e+03, gap 0.0090%
#
# User-callback calls 240845, time in user-callback 5.55 sec
# Saved full RunArtifacts to results\gtep_output\aggregated\aggregated_75c4e3c6_e02b9a47.pkl
# [case_02] Aggregated GTEP solved with objective 9653.469928912078
# [case_02] Solving spatial de-aggregation GTEP...
# === DATA LOADING ===
# PV shape  (384, 17)
# Wind shape  (384, 17)
# Load shape  (384, 17)
#
#
# === SCALING CHECK ===
# Power: MW → GW (×0.001), Cost: $ → M$ (×1e-06)
#     PV CF range: [0, 0.866]
#     Wind CF range: [0, 1]
#     Load range MW → GW:  [441, 5.83e+03] → [0.441, 5.83]
#     Param range: [30.6, 2.36e+06] → [0.0306, 2.36e+03]
#
# Set parameter Username
# Set parameter TimeLimit to value 14400
# Set parameter Threads to value 8
# Academic license - for non-commercial use only - expires 2026-08-14
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  14400
# Threads  8
#
# Optimize a model with 156924 rows, 91596 columns and 472537 nonzeros
# Model fingerprint: 0x39726f04
# Variable types: 91579 continuous, 17 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 4e+00]
#   Objective range  [2e-01, 6e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-03, 2e+03]
# Found heuristic solution: objective 1376566.5724
# Presolve removed 68101 rows and 27217 columns
# Presolve time: 0.75s
# Presolved: 88823 rows, 64379 columns, 278264 nonzeros
# Found heuristic solution: objective 1376551.9424
# Variable types: 64372 continuous, 7 integer (0 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    62947    2.2218392e+05   0.000000e+00   4.160319e+07      5s
#    81905    1.4605102e+05   0.000000e+00   3.073678e+08     10s
#    91563    1.1937806e+05   0.000000e+00   7.873763e+07     15s
#    95693    9.9895240e+04   0.000000e+00   8.089187e+07     20s
#    99253    7.2421762e+04   0.000000e+00   2.248368e+09     25s
#   103805    3.8439412e+04   0.000000e+00   6.267206e+06     30s
#   106919    3.1193215e+04   0.000000e+00   1.497882e+08     35s
#   109298    2.5050007e+04   0.000000e+00   7.804390e+07     40s
#   112119    2.1925258e+04   0.000000e+00   7.451021e+07     45s
#   114471    2.0235957e+04   0.000000e+00   2.378489e+07     50s
#   116870    1.8325085e+04   0.000000e+00   4.152338e+06     55s
#   118910    1.6886831e+04   0.000000e+00   9.110187e+06     60s
#   121050    1.5550217e+04   0.000000e+00   8.887937e+06     65s
#      3     7 9662.41580    2    5 9662.68845 9661.33941  0.01% 15689  324s
#      6     5 9662.11536    3    4 9662.68845 9661.35354  0.01% 13771  348s
#     12     7 9662.37502    4    2 9662.68845 9661.65539  0.01%  9286  376s
#
# Cutting planes:
#   Gomory: 3
#
# Explored 14 nodes (457555 simplex iterations) in 376.41 seconds (328.16 work units)
# Thread count was 8 (of 12 available processors)
#
# Solution count 3: 9662.69 1.37655e+06 1.37657e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.662688450607e+03, best bound 9.662121374691e+03, gap 0.0059%
#
# User-callback calls 99574, time in user-callback 1.38 sec
# Saved full RunArtifacts to results\gtep_output\spatial\spatial_75c4e3c6_d3ecd59c.pkl
# [case_02] Spatial results saved to results\gtep_output\spatial\spatial_75c4e3c6_d3ecd59c.pkl with objective 9662.688450607153
# [case_02] Solving temporal de‑aggregation GTEP...
# === DATA LOADING ===
# PV shape  (8760, 17)
# Wind shape  (8760, 17)
# Load shape  (8760, 17)
#
#
# === SCALING CHECK ===
# Power: MW → GW (×0.001), Cost: $ → M$ (×1e-06)
#     PV CF range: [0, 0.866]
#     Wind CF range: [0, 1]
#     Load range MW → GW:  [401, 6.13e+03] → [0.401, 6.13]
#     Param range: [30.6, 2.36e+06] → [0.0306, 2.36e+03]
#
# Set parameter Username
# Set parameter TimeLimit to value 7200
# Set parameter Threads to value 8
# Academic license - for non-commercial use only - expires 2026-08-14
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  7200
# Threads  8
#
# Optimize a model with 3574080 rows, 2084880 columns and 7297029 nonzeros
# Model fingerprint: 0xd93cc7b9
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+00]
#   Objective range  [3e-02, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-05, 1e+01]
# Presolve removed 3034672 rows and 927182 columns (presolve time = 5s)...
# Presolve removed 3157337 rows and 927578 columns
# Presolve time: 7.39s
# Presolved: 416743 rows, 1279942 columns, 2407336 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Elapsed ordering time = 6s
# Ordering time: 8.10s
#
# Barrier statistics:
#  AA' NZ     : 1.102e+06
#  Factor NZ  : 2.739e+07 (roughly 900 MB of memory)
#  Factor Ops : 5.054e+09 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.14009681e+06 -1.51008485e+06  4.28e+01 0.00e+00  7.98e+00    18s
#    1   9.12869720e+05 -1.04113676e+06  6.11e+00 5.33e-15  1.37e+00    19s
#    2   3.99355780e+05 -4.73203768e+05  2.63e+00 6.22e-15  5.21e-01    20s
#    3   1.74458454e+05 -2.04190327e+05  1.08e+00 2.31e-14  1.97e-01    21s
#    4   8.58093220e+04 -8.59459094e+04  4.67e-01 5.15e-14  8.10e-02    22s
#    5   6.71285339e+04 -3.93157822e+04  3.35e-01 7.82e-14  4.86e-02    22s
#    6   4.80662784e+04 -1.30483264e+04  2.01e-01 3.73e-14  2.69e-02    23s
#    7   3.62846112e+04  1.52120996e+03  1.17e-01 4.62e-14  1.49e-02    24s
#    8   2.81910163e+04  9.50628943e+03  6.15e-02 4.44e-14  7.81e-03    25s
#    9   2.46958053e+04  1.36027139e+04  3.83e-02 4.09e-14  4.58e-03    26s
#   10   2.24208797e+04  1.54846345e+04  2.32e-02 7.28e-14  2.84e-03    27s
#   11   2.15024802e+04  1.61315428e+04  1.72e-02 6.57e-14  2.19e-03    28s
#   45   1.87698829e+04  1.87696977e+04  1.07e-06 3.02e-14  7.56e-08    61s
#   46   1.87698558e+04  1.87697341e+04  7.74e-07 1.95e-14  4.99e-08    62s
#   47   1.87698437e+04  1.87697393e+04  6.43e-07 2.13e-14  4.27e-08    63s
#   48   1.87698201e+04  1.87697481e+04  3.84e-07 2.13e-14  2.93e-08    64s
#   49   1.87698116e+04  1.87697661e+04  2.92e-07 2.84e-14  1.87e-08    65s
#   50   1.87697925e+04  1.87697753e+04  8.40e-08 3.91e-14  6.95e-09    66s
#   51   1.87697853e+04  1.87697812e+04  1.04e-08 3.55e-14  1.64e-09    67s
#   52   1.87697846e+04  1.87697840e+04  2.88e-09 4.62e-14  2.22e-10    68s
#   53   1.87697843e+04  1.87697842e+04  2.52e-10 4.26e-14  2.81e-11    69s
#
# Barrier solved model in 53 iterations and 69.50 seconds (33.91 work units)
# Optimal objective 1.87697843e+04
#
# Crossover log...
#
#    70671 DPushes remaining with DInf 0.0000000e+00                71s
#        0 DPushes remaining with DInf 0.0000000e+00                73s
#
#   402318 PPushes remaining with PInf 1.6026117e-03                73s
#   271553 PPushes remaining with PInf 8.1754147e-05                75s
#   211500 PPushes remaining with PInf 9.3431001e-06                80s
#   179374 PPushes remaining with PInf 9.3431001e-06                85s
#   159027 PPushes remaining with PInf 9.3431001e-06                90s
#   143652 PPushes remaining with PInf 9.3431001e-06                95s
#    91394 PPushes remaining with PInf 0.0000000e+00               100s
#    39182 PPushes remaining with PInf 0.0000000e+00               105s
#        0 PPushes remaining with PInf 0.0000000e+00               109s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 4.4096123e-13    109s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   450467    1.8769784e+04   0.000000e+00   0.000000e+00    111s
#
# Solved in 450467 iterations and 111.40 seconds (49.81 work units)
# Optimal objective  1.876978427e+04
#
# User-callback calls 457532, time in user-callback 1.36 sec
# Saved full RunArtifacts to results\gtep_output\temporal\temporal_75c4e3c6_d3ecd59c.pkl
# [case_02] Temporal results saved to results\gtep_output\temporal\temporal_75c4e3c6_d3ecd59c.pkl with objective 18769.784272370303
#
# === All cases completed ===
#         id     desc     stage error  agg_hash gtep_hash  \
# 0  case_01  C10-D12       agg  None  8a7dce83  bca22cb9
# 1  case_01  C10-D12   spatial  None  8a7dce83  d3ecd59c
# 2  case_01  C10-D12  temporal  None  8a7dce83  d3ecd59c
# 3  case_02  C12-D16       agg  None  75c4e3c6  e02b9a47
# 4  case_02  C12-D16   spatial  None  75c4e3c6  d3ecd59c
# 5  case_02  C12-D16  temporal  None  75c4e3c6  d3ecd59c
#
#                                        artifact_path     objective
# 0  results\gtep_output\aggregated\aggregated_8a7d...   9410.401851
# 1  results\gtep_output\spatial\spatial_8a7dce83_d...   9521.629453
# 2  results\gtep_output\temporal\temporal_8a7dce83...  23178.288204
# 3  results\gtep_output\aggregated\aggregated_75c4...   9653.469929
# 4  results\gtep_output\spatial\spatial_75c4e3c6_d...   9662.688451
# 5  results\gtep_output\temporal\temporal_75c4e3c6...  18769.784272
